# %% [markdown]
# <a href="https://colab.research.google.com/github/JyothikaKancharla/FmmlLab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 15:43:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   190MB/s    in 0.4s
#
# 2024-04-01 15:43:56 (190 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5924    1302.4549v2  This paper investigates graph clustering in th...    cs
# 12312  1711.07033v3  This paper presents a novel decentralized high...  stat
# 26023  1608.03474v1  With increasing demand for efficient image and...    cs
# 22591  1702.03522v2  Spectral clustering is amongst the most popula...  stat
# 1487   1611.05546v2  Part of the appeal of Visual Question Answerin...    cs
# ...             ...                                                ...   ...
# 26122  1608.07897v2  Fingerprint is widely used in a variety of app...    cs
# 27259  1703.00534v1  As one kind of skin cancer, melanoma is very d...    cs
# 36869  1507.05956v6  This paper describes the IBM 704 architecture ...    cs
# 30995  1802.00671v1  In this work, a novel deep learning technique ...    cs
# 21578   1103.5201v2  We theoretically investigate the convergence r...  stat
#
#                                                    title  year  \
# 5924   Breaking the Small Cluster Barrier of Graph Cl...  2013
# 12312  Decentralized High-Dimensional Bayesian Optimi...  2017
# 26023  Learning Dynamic Hierarchical Models for Anyti...  2016
# 22591  Spectral Clustering via Graph Filtering: Consi...  2017
# 1487                 Zero-Shot Visual Question Answering  2016
# ...                                                  ...   ...
# 26122  Using k-nearest neighbors to construct cancela...  2016
# 27259  Skin cancer reorganization and classification ...  2017
# 36869  Towards a Better Understanding of CAR, CDR, CA...  2015
# 30995  Handwritten Isolated Bangla Compound Character...  2018
# 21578  Sharp Convergence Rate and Support Consistency...  2011
#
#                                                 keywords
# 5924   [investigates, clustering, traditional, algori...
# 12312  [decentralized, dimensional, optimization, alg...
# 26023  [increasing, efficient, sensitive, application...
# 22591  [clustering, community, detection, clustering,...
# 1487   [answering, questions, previously, questions, ...
# ...                                                  ...
# 26122  [fingerprint, applications, fingerprint, cance...
# 27259  [dangerous, dermoscopy, detection, recarboniza...
# 36869  [describes, architecture, themselves, compound...
# 30995  [technique, recognition, handwritten, characte...
# 21578  [theoretically, investigate, convergence, cons...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5924     [investigates, clustering, traditional, algori...
# 12312    [decentralized, dimensional, optimization, alg...
# 26023    [increasing, efficient, sensitive, application...
# 22591    [clustering, community, detection, clustering,...
# 1487     [answering, questions, previously, questions, ...
#                                ...
# 21984    [interaction, transitivity, empirical, transit...
# 22749    [predictive, recurrent, filtering, prediction,...
# 360      [recognition, representation, chemistry, devel...
# 2124     [nonmyopic, framework, lipschitz, continuous, ...
# 6999     [unsupervised, clustering, dimensional, electr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8656 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="63cecc6e-a75f-4063-bd60-4590396ab907" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63cecc6e-a75f-4063-bd60-4590396ab907")) {                    Plotly.newPlot(                        "63cecc6e-a75f-4063-bd60-4590396ab907",                        [{"x":["structured","sufficiently","assumptions","carefully","presenting","particular","necessarily","iterative","traditional","restriction","statistics","procedure","constructed","dimensional","investigates","algorithm","relaxation","clustering","correctly","observation","existence","experiments","knowledge","distributed","representation","evaluation","outperforms","efficiently","synthetic","designing","dimensions","interdependent","exploited","empirical","components","asymptotically","acquisition","objective","decentralized","optimization","similarly","represented","performance","optimized","dimension","characterizing","guarantee","scalability","algorithms","requiring","sensitive","iteration","mechanism","selection","advantages","demonstrate","applications","formulate","incorporates","prediction","computation","segmentation","hierarchical","efficient","continuous","optimizes","inference","increasing","approximate","efficiency","performances","decomposition","laplacian","filtering","computing","approximation","dimensionality","conditions","implement","prohibitively","community","detection","performed","embedding","stochastic","consistently","eigenvectors","consistency","embeddings","retrieval","pretrained","previously","answering","highlights","approaches","deficiencies","significant","baselines","achieving","illustrate","classifiers","strategies","therefore","extensive","prohibitive","including","capability","practical","questions","generalize","posteriors","theoretically","estimators","derivative","corresponds","importance","specifically","variational","distributions","estimator","parameters","reparameterized","posterior","empirically","different","automatic","translation","approximations","developed","identifying","consuming","expensive","equivalent","intervention","translations","evaluations","important","representative","methodology","experimentally","framework","regression","dramatically","sufficient","measurement","simultaneously","introduce","collected","maximizes","terminate","computationally","distortion","supervised","measurements","improvement","application","information","reconstructions","underlying","radiation","techniques","generated","reconstruct","potential","reduction","recognizing","surveillance","individual","neighbors","identification","signature","classified","classification","transform","frequency","intensive","operators","influence","canonical","polymorphisms","interactions","effective","nonlinear","covariance","association","classical","investigate","synthesized","interaction","nonparametric","nucleotide","contaminated","statistic","correlation","relationship","basically","resampling","extraction","regressions","summarized"],"y":[123,29,67,19,20,266,23,88,177,5,60,124,51,163,26,826,22,155,36,55,36,634,354,103,414,264,266,135,135,43,44,2,33,157,83,10,38,161,6,332,23,72,871,60,60,12,33,37,610,48,65,39,122,197,78,560,432,49,30,250,154,191,109,379,113,15,199,116,100,152,40,57,17,62,132,100,67,114,72,10,87,351,114,103,137,42,6,55,87,114,7,110,69,11,455,3,251,55,78,79,114,105,147,174,6,247,61,156,81,50,2,35,14,5,20,95,162,53,107,20,246,0,38,69,776,170,109,38,208,84,36,74,58,18,17,38,395,38,55,44,567,119,28,68,31,115,324,74,9,2,104,16,197,58,146,240,697,15,101,5,370,163,33,144,120,37,37,120,19,106,12,26,516,62,58,20,44,62,19,0,80,240,47,18,26,95,158,15,83,16,0,3,4,75,61,4,4,130,0,6],"type":"bar"},{"x":["structured","sufficiently","assumptions","carefully" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>Generate</span> <span style=''>Chairs</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Nets</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>(GANs)</span> <span style=''>has</span> <span style=''>gained</span> <span style='background-color:rgba(0, 255, 0, 0.5199999999999999);'>tremendous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>popularity</span> <span style=''>lately</span> <span style=''>due</span> <span style=''>to</span> <span style=''>an</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reinforce</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.4975845410628019);'>predictive</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>with</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>feedback</span> <span style=''>GANs</span> <span style=''>allow</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>synthesize</span> <span style=''>images</span> <span style=''>with</span> <span style=''>a</span> <span style=''>high</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>realism</span> <span style=''>However</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>of</span> <span style=''>such</span> <span style=''>models</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitation</span> <span style=''>for</span> <span style=''>such</span> <span style=''>models</span> <span style=''>were</span> <span style=''>found</span> <span style=''>It</span> <span style=''>affects</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>certain</span> <span style=''>layers</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinearities</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>designing</span> <span style='background-color:rgba(0, 255, 0, 0.358288770053476);'>architectures</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>allow</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(0, 255, 0, 0.6027088036117382);'>convolutional</span> <span style=''>GAN</span> <span style=''>models</span> <span style=''>with</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>connected</span> <span style=''>hidden</span> <span style=''>layers</span> <span style=''>In</span> <span style=''>our</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Total</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Variation</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypergraphs</span> <span style=''>Learning</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypergraphs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Revisited</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Hypergraphs</span> <span style=''>allow</span> <span style=''>one</span> <span style=''>to</span> <span style=''>encode</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>in</span> <span style=''>data</span> <span style=''>and</span> <span style=''>are</span> <span style=''>thus</span> <span style=''>a</span> <span style=''>very</span> <span style=''>flexible</span> <span style=''>modeling</span> <span style=''>tool</span> <span style=''>Current</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>either</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypergraphs</span> <span style=''>via</span> <span style=''>graphs</span> <span style=''>or</span> <span style=''>on</span> <span style=''>tensor</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>are</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>under</span> <span style=''>special</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypergraphs</span> <span style=''>which</span> <span style=''>fully</span> <span style=''>uses</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypergraph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>The</span> <span style=''>key</span> <span style=''>element</span> <span style=''>is</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functionals</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>total</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypergraphs</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>BayesOpt</span> <span style=''>A</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>Library</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3733333333333333);'>Nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3517495395948434);'>Experimental</span> <span style=''>Design</span> <span style=''>and</span> <span style=''>Bandits</span> <br/><br/><span style=''>BayesOpt</span> <span style=''>is</span> <span style=''>a</span> <span style=''>library</span> <span style=''>with</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>solve</span> <span style='background-color:rgba(255, 0, 0, 0.3733333333333333);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3132832080200502);'>stochastic</span> <span style=''>bandits</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3517495395948434);'>experimental</span> <span style=''>design</span> <span style=''>problems</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>by</span> <span style=''>building</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6218905472636816);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>evidence</span> <span style=''>and</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.39920948616600793);'>knowledge</span> <span style=''>for</span> <span style=''>the</span> <span style=''>target</span> <span style=''>function</span> <span style=''>Built</span> <span style=''>in</span> <span style=''>standard</span> <span style=''>C</span> <span style=''>the</span> <span style=''>library</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>while</span> <span style=''>being</span> <span style=''>portable</span> <span style=''>and</span> <span style=''>flexible</span> <span style=''>It</span> <span style=''>includes</span> <span style=''>a</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 0.5675675675675675);'>interface</span> <span style=''>for</span> <span style=''>C</span> <span style=''>C</span> <span style=''>Python</span> <span style=''>Matlab</span> <span style=''>and</span> <span style=''>Octave</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>The</span> <span style=''>Sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthesis</span> <span style=''>model</span> <span style=''>signals</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>atoms</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>process</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>set</span> <span style=''>of</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>While</span> <span style=''>ideally</span> <span style=''>this</span> <span style=''>would</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>factors</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>it</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>average</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>samples</span> <span style=''>The</span> <span style=''>main</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>estimate</span> <span style=''>that</span> <span style=''>controls</span> <span style=''>to</span> <span style=''>what ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10576923076923077)
# 	knowledge (0.12606837606837606)
# 	segmentation (0.06801994301994302)
# 	architecture (0.0876068376068376)
# 	representation (0.14743589743589744)
# 	information (0.2482193732193732)
# 	detection (0.125)
# 	different (0.27635327635327633)
# 	convolutional (0.12642450142450143)
# 	recognition (0.13105413105413105)
#
# Some Statistics words are:
# 	variational (0.10240963855421686)
# 	variables (0.14156626506024098)
# 	theoretical (0.1495983935742972)
# 	algorithm (0.39558232931726905)
# 	statistical (0.16214859437751003)
# 	distribution (0.18423694779116465)
# 	estimation (0.17520080321285142)
# 	inference (0.19979919678714858)
# 	dimensional (0.19026104417670683)
# 	regression (0.18724899598393574)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f61302ae-6d62-4b72-ac97-067dfddf07f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f61302ae-6d62-4b72-ac97-067dfddf07f1")) {                    Plotly.newPlot(                        "f61302ae-6d62-4b72-ac97-067dfddf07f1",                        [{"x":["structured","sufficiently","assumptions","carefully","presenting","particular","necessarily","iterative","traditional","restriction","statistics","procedure","constructed","dimensional","investigates","algorithm","relaxation","clustering","correctly","observation","existence","experiments","knowledge","distributed","representation","evaluation","outperforms","efficiently","synthetic","designing","dimensions","interdependent","exploited","empirical","components","asymptotically","acquisition","objective","decentralized","optimization","similarly","represented","performance","optimized","dimension","characterizing","guarantee","scalability","algorithms","requiring","sensitive","iteration","mechanism","selection","advantages","demonstrate","applications","formulate","incorporates","prediction","computation","segmentation","hierarchical","efficient","continuous","optimizes","inference","increasing","approximate","efficiency","performances","decomposition","laplacian","filtering","computing","approximation","dimensionality","conditions","implement","prohibitively","community","detection","performed","embedding","stochastic","consistently","eigenvectors","consistency","embeddings","retrieval","pretrained","previously","answering","highlights","approaches","deficiencies","significant","baselines","achieving","illustrate","classifiers","strategies","therefore","extensive","prohibitive","including","capability","practical","questions","generalize","posteriors","theoretically","estimators","derivative","corresponds","importance","specifically","variational","distributions","estimator","parameters","reparameterized","posterior","empirically","different","automatic","translation","approximations","developed","identifying","consuming","expensive","equivalent","intervention","translations","evaluations","important","representative","methodology","experimentally","framework","regression","dramatically","sufficient","measurement","simultaneously","introduce","collected","maximizes","terminate","computationally","distortion","supervised","measurements","improvement","application","information","reconstructions","underlying","radiation","techniques","generated","reconstruct","potential","reduction","recognizing","surveillance","individual","neighbors","identification","signature","classified","classification","transform","frequency","intensive","operators","influence","canonical","polymorphisms","interactions","effective","nonlinear","covariance","association","classical","investigate","synthesized","interaction","nonparametric","nucleotide","contaminated","statistic","correlation","relationship","basically","resampling","extraction","regressions","summarized","understanding","regularized","visualization","restricting","cornerstones","movements","financial","relationships","environmental","volatility","associated","landscape","automatically","partially","performing","explained","represent","economics","genuinely","decomposed","organized","influencing","quantifying","examination","formulation","appropriately","complexity","factorization","completion","quadratic","solutions","constrained","combinatorial","constraints","semidefinite","quadratically","participants","recognition","modifiers","sentences","assignments","descriptions","participant","prepositional","relations","characteristics","linguistic","adjectival","properties","adverbial","sentential","extracting","available","obtaining" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reparameterized
# 	polymorphisms
# 	nucleotide
# 	regressions
# 	genuinely
# 	envelopes
# 	aerodynamic
# 	tractography
# 	refitting
# 	imperceptible
# 	martingale
# 	propensity
# 	transplantation
# 	purchases
# 	degeneracy
# 	stratification
# 	sparsities
# 	suboptimality
# 	allocating
# 	selectors
# Some words which never appear in Statistics papers:
# 	modifiers
# 	prepositional
# 	adjectival
# 	adverbial
# 	sentential
# 	recognizer
# 	depicting
# 	lemmatization
# 	societies
# 	homography
# 	radiologists
# 	hemorrhage
# 	discarded
# 	responded
# 	departments
# 	evidences
# 	programmers
# 	reflection
# 	navigating
# 	undiscovered

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062318174858368e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7516666666666667
